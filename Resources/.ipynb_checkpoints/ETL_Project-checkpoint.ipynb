# %%
import pandas as pd
from sqlalchemy import create_engine

import sqlite3

# %%
conn = sqlite3.connect('austinproject2.sqlite')

# %%
c = conn.cursor()
conn.execute('drop table if exists aac_outcomes')
conn.execute('drop table if exists city_satisfaction')

# %%
c.execute('''CREATE TABLE aac_outcomes
    (id integer PRIMARY KEY AUTO_INCREMENT,
    year integer, 
    animal_type VARCHAR(30), 
    outcome_type VARCHAR(30),
    age_upon_outcome TEXT,
    breed TEXT)''')

# %%
c.execute('''CREATE TABLE city_satisfaction
    (id INT PRIMARY KEY,
    year INT,
    quality_of_life VARCHAR(20),
    parks_and_rec VARCHAR(20),
    animal_services VARCHAR(20),
    safety_day VARCHAR(20),
    safety_night VARCHAR(20),
    safety_parks VARCHAR(20),
    num_parks VARCHAR(20),
    num_trails VARCHAR(20),
    park_appearance VARCHAR(20),
    age_range TEXT,
    income_range TEXT,
    zip_code integer)''')

# %%
conn.commit()

# %% [markdown]
# ## Extract the CSVs into DataFrames

# %%
aac_outcomes_csv = "Austin_Animal_Center_Outcomes.csv"
aac_outcomes_df = pd.read_csv(aac_outcomes_csv)
aac_outcomes_df.head()
# Out:
#   Animal ID      Name                DateTime               MonthYear  \
# 0   A771830  *Bradley  12/27/2018 01:25:00 PM  12/27/2018 01:25:00 PM
# 1   A779576    *Rajah  10/01/2018 05:03:00 PM  10/01/2018 05:03:00 PM
# 2   A741715  *Pebbles  01/11/2017 06:17:00 PM  01/11/2017 06:17:00 PM
# 3   A658751     Benji  11/13/2016 01:38:00 PM  11/13/2016 01:38:00 PM
# 4   A721285       NaN  02/24/2016 02:42:00 PM  02/24/2016 02:42:00 PM
#
#   Date of Birth     Outcome Type Outcome Subtype Animal Type Sex upon Outcome  \
# 0    05/10/2017         Adoption          Foster         Dog    Neutered Male
# 1    04/18/2018         Adoption             NaN         Cat    Neutered Male
# 2    03/07/2016         Adoption             NaN         Cat    Spayed Female
# 3    07/14/2011  Return to Owner             NaN         Dog    Neutered Male
# 4    02/24/2014       Euthanasia       Suffering       Other          Unknown
#
#   Age upon Outcome                   Breed        Color
# 0           1 year            Pit Bull Mix   White/Blue
# 1         5 months  Domestic Shorthair Mix  Brown Tabby
# 2        10 months  Domestic Shorthair Mix       Calico
# 3          5 years      Border Terrier Mix          Tan
# 4          2 years             Raccoon Mix   Black/Gray

# %%
city_satisfaction_csv = "Community_Survey_2015__2016___2017.csv"
city_satisfaction_df = pd.read_csv(city_satisfaction_csv)
city_satisfaction_df.head()
# Out:
# /Users/kerrykovacik/anaconda3/envs/PythonData3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (29,30,45) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#      ID  Year Method The City of Austin as a place to live  \
# 0  1873  2015    NaN                             Satisfied
# 1  1692  2015    NaN                               Neutral
# 2  1968  2015    NaN                             Satisfied
# 3  1474  2015    NaN                             Satisfied
# 4  1794  2015    NaN                             Satisfied
#
#   The City of Austin as a place to raise children  \
# 0                                       Satisfied
# 1                                         Neutral
# 2                                       Satisfied
# 3                                       Satisfied
# 4                                         Neutral
#
#   The City of Austin as a place to work  \
# 0                             Satisfied
# 1                               Neutral
# 2                             Satisfied
# 3                             Satisfied
# 4                               Neutral
#
#   The City of Austin as a place to retire  \
# 0                               Satisfied
# 1                                 Neutral
# 2                               Satisfied
# 3                            Dissatisfied
# 4                               Satisfied
#
#   Overall value that you receive for your city tax dollars and fees  \
# 0                                            Neutral
# 1                                            Neutral
# 2                                            Neutral
# 3                                          Satisfied
# 4                                          Satisfied
#
#   Overall quality of life in the city  \
# 0                             Neutral
# 1                          Don't Know
# 2                             Neutral
# 3                        Dissatisfied
# 4                           Satisfied
#
#   How well the City of Austin is planning growth           ...            \
# 0                                        Neutral           ...
# 1                                     Don't Know           ...
# 2                                   Dissatisfied           ...
# 3                                        Neutral           ...
# 4                                        Neutral           ...
#
#   How many children, if any, do you have in your household who use childcare services such asdaycare, after school programs, and/or camps?  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Which of the following best describes your annual household income?  \
# 0                                        $40K-59,999
# 1                                        $60K-79,999
# 2                                       $80K-149,999
# 3                                     less than $20K
# 4                                        $60K-79,999
#
#   What is your gender? Do you own or rent your home?  \
# 0                 Male                           Own
# 1               Female                          Rent
# 2               Female                           Own
# 3                 Male                           Own
# 4                 Male                           Own
#
#   What is your HOME zip code? (Self-Reported) Zip Code Council District  \
# 0                                     78745.0    78745                2
# 1                                     78744.0    78744                2
# 2                                     78729.0    78729                6
# 3                                     78741.0    78741                3
# 4                                     78752.0    78752                4
#
#   Block Level X Longitude Block Level Y Latitude         Date as of Date
# 0                 -97.780                 30.197  01/01/2015 12:00:00 AM
# 1                 -97.756                 30.172  01/01/2015 12:00:00 AM
# 2                 -97.775                 30.460  01/01/2015 12:00:00 AM
# 3                 -97.695                 30.239  01/01/2015 12:00:00 AM
# 4                 -97.705                 30.332  01/01/2015 12:00:00 AM
#
# [5 rows x 157 columns]

# %% [markdown]
# ## Transform the DataFrames

# %%
new_aac_outcomes_df = aac_outcomes_df[['Animal ID', 'DateTime', 'Outcome Type', 'Animal Type', 'Breed', 'Age upon Outcome']].copy()
new_aac_outcomes_df = new_aac_outcomes_df.rename(index=str, columns={"Animal ID": "id","DateTime": "year", "Outcome Type": "outcome_type", "Animal Type": "animal_type", "Breed":"breed", "Age upon Outcome": "age_upon_outcome"})
new_aac_outcomes_df.set_index("id", inplace=True)
new_aac_outcomes_df['year']
# new_animals_df.drop_duplicates("id", inplace=True)
# Out:
# id
# A771830    12/27/2018 01:25:00 PM
# A779576    10/01/2018 05:03:00 PM
# A741715    01/11/2017 06:17:00 PM
# A658751    11/13/2016 01:38:00 PM
# A721285    02/24/2016 02:42:00 PM
# A746650    04/07/2017 11:58:00 AM
# A750122    05/24/2017 06:36:00 PM
# A756696    09/01/2017 11:23:00 AM
# A784168    11/14/2018 12:33:00 PM
# A707443    07/13/2015 01:50:00 PM
# A666430    11/07/2013 11:47:00 AM
# A675708    06/03/2014 02:20:00 PM
# A680386    06/15/2014 03:50:00 PM
# A684346    07/22/2014 04:04:00 PM
# A754895    07/30/2017 12:03:00 PM
# A683115    07/07/2014 02:04:00 PM
# A664462    10/07/2013 01:06:00 PM
# A785671    12/07/2018 05:36:00 PM
# A762837    12/02/2017 04:24:00 PM
# A713785    10/19/2015 02:55:00 PM
# A741783    01/12/2017 05:02:00 PM
# A764447    01/18/2018 04:59:00 PM
# A697000    02/16/2015 01:24:00 PM
# A777321    08/23/2018 07:00:00 PM
# A697055    02/17/2015 03:06:00 PM
# A646449    07/23/2015 06:31:00 PM
# A784995    11/25/2018 11:44:00 AM
# A724228    05/28/2016 04:40:00 PM
# A781882    10/08/2018 12:00:00 AM
# A708122    07/27/2015 02:21:00 PM
#                     ...
# A788326    01/30/2019 09:27:00 PM
# A787475    01/16/2019 10:00:00 AM
# A607663    01/31/2019 07:55:00 AM
# A787635    01/21/2019 12:42:00 PM
# A788240    01/29/2019 08:47:00 AM
# A780683    01/31/2019 09:41:00 AM
# A788307    01/31/2019 10:31:00 AM
# A748433    05/03/2017 02:15:00 PM
# A773212    01/31/2019 12:37:00 PM
# A783279    01/31/2019 11:55:00 AM
# A788063    01/31/2019 12:15:00 PM
# A740163    01/31/2019 01:46:00 PM
# A776324    07/17/2018 05:30:00 PM
# A685124    01/31/2019 01:50:00 PM
# A787620    01/21/2019 11:51:00 AM
# A786266    01/31/2019 02:32:00 PM
# A787296    01/31/2019 02:34:00 PM
# A785895    01/31/2019 02:33:00 PM
# A788283    01/31/2019 02:09:00 PM
# A776324    01/31/2019 02:00:00 PM
# A788336    01/31/2019 02:00:00 PM
# A787788    01/31/2019 02:34:00 PM
# A787327    01/31/2019 02:32:00 PM
# A784715    01/31/2019 02:33:00 PM
# A788136    01/31/2019 03:09:00 PM
# A788329    01/31/2019 03:27:00 PM
# A788087    01/26/2019 06:06:00 PM
# A759491    01/31/2019 04:17:00 PM
# A722968    01/31/2019 04:59:00 PM
# A780441    01/31/2019 04:14:00 PM
# Name: year, Length: 95138, dtype: object

# %%
new_aac_outcomes_df['year'] = pd.DatetimeIndex(new_aac_outcomes_df['year']).year

# %%
new_aac_outcomes_df['year'].value_counts()
#we need to drop 2013, 2014, 2018, 2019
# Out:
# 2014    18709
# 2015    18506
# 2016    17671
# 2017    17656
# 2018    16731
# 2013     4505
# 2019     1360
# Name: year, dtype: int64

# %%
new_aac_outcomes_df = new_aac_outcomes_df[new_aac_outcomes_df.year != 2013]
new_aac_outcomes_df = new_aac_outcomes_df[new_aac_outcomes_df.year != 2014]
new_aac_outcomes_df = new_aac_outcomes_df[new_aac_outcomes_df.year != 2018]
new_aac_outcomes_df = new_aac_outcomes_df[new_aac_outcomes_df.year != 2019]

# %%
new_aac_outcomes_df['outcome_type'] = new_aac_outcomes_df['outcome_type'].replace('Disposal', 'Died')

# %%
new_aac_outcomes_df['outcome_type'] = new_aac_outcomes_df['outcome_type'].replace('Rto-Adopt', 'Return to Owner')

# %%
new_aac_outcomes_df.head()
# Out:
#          year     outcome_type animal_type  \
# id
# A741715  2017         Adoption         Cat
# A658751  2016  Return to Owner         Dog
# A721285  2016       Euthanasia       Other
# A746650  2017  Return to Owner         Dog
# A750122  2017         Transfer         Dog
#
#                                            breed age_upon_outcome
# id
# A741715                   Domestic Shorthair Mix        10 months
# A658751                       Border Terrier Mix          5 years
# A721285                              Raccoon Mix          2 years
# A746650  Labrador Retriever/Jack Russell Terrier           1 year
# A750122                   Labrador Retriever Mix          1 month

# %%
new_aac_outcomes_df.groupby(['year','animal_type','outcome_type']).count()
# Out:
#                                   breed  age_upon_outcome
# year animal_type outcome_type
# 2015 Bird        Adoption            16                16
#                  Died                 1                 1
#                  Euthanasia          14                14
#                  Relocate             3                 3
#                  Return to Owner      2                 2
#                  Transfer            11                11
#      Cat         Adoption          2873              2873
#                  Died               114               114
#                  Euthanasia         428               428
#                  Missing              7                 7
#                  Return to Owner    342               342
#                  Transfer          3575              3575
#      Dog         Adoption          4476              4476
#                  Died                35                35
#                  Euthanasia         420               420
#                  Missing              7                 7
#                  Return to Owner   3151              3151
#                  Transfer          2178              2178
#      Livestock   Transfer             2                 2
#      Other       Adoption            12                12
#                  Died                59                59
#                  Euthanasia         604               604
#                  Relocate             1                 1
#                  Return to Owner     10                10
#                  Transfer           165               165
# 2016 Bird        Adoption            56                56
#                  Died                20                20
#                  Euthanasia          37                37
#                  Missing              1                 1
#                  Relocate             2                 2
# ...                                 ...               ...
#      Other       Died                86                86
#                  Euthanasia         708               708
#                  Relocate             2                 2
#                  Return to Owner      9                 9
#                  Transfer            82                82
# 2017 Bird        Adoption            24                24
#                  Died                 4                 4
#                  Euthanasia          26                26
#                  Relocate             1                 1
#                  Return to Owner      2                 2
#                  Transfer            30                30
#      Cat         Adoption          3274              3274
#                  Died               104               104
#                  Euthanasia         249               249
#                  Missing              3                 3
#                  Return to Owner    370               370
#                  Transfer          2575              2575
#      Dog         Adoption          4691              4691
#                  Died                32                32
#                  Euthanasia          97                97
#                  Missing              3                 3
#                  Return to Owner   2977              2977
#                  Transfer          2143              2143
#      Livestock   Transfer             1                 1
#      Other       Adoption           103               103
#                  Died                97                97
#                  Euthanasia         712               712
#                  Relocate             1                 1
#                  Return to Owner     11                11
#                  Transfer           125               125
#
# [76 rows x 2 columns]

# %%
new_aac_outcomes_df.head()
# Out:
#          year     outcome_type animal_type  \
# id
# A741715  2017         Adoption         Cat
# A658751  2016  Return to Owner         Dog
# A721285  2016       Euthanasia       Other
# A746650  2017  Return to Owner         Dog
# A750122  2017         Transfer         Dog
#
#                                            breed age_upon_outcome
# id
# A741715                   Domestic Shorthair Mix        10 months
# A658751                       Border Terrier Mix          5 years
# A721285                              Raccoon Mix          2 years
# A746650  Labrador Retriever/Jack Russell Terrier           1 year
# A750122                   Labrador Retriever Mix          1 month

# %%
new_city_satisfaction_df = city_satisfaction_df[["ID", "Year", "Overall quality of life in the city", "Overall quality of city parks and recreation", "Animal services (shelter, adoptions, animal control, etc.)","I feel safe in my neighborhood during the day", "I feel safe in my neighborhood at night","I feel safe in city parks","Number of City of Austin parks","Number of City of Austin walking/biking trails","Appearance of City of Austin park grounds located in Austin","Which of the following best describes your AGE?","Which of the following best describes your annual household income?","Zip Code"]].copy()
new_city_satisfaction_df = new_city_satisfaction_df.rename(index=str, columns={"ID": "id", "Year": "year", "Overall quality of life in the city": "quality_of_life", "Overall quality of city parks and recreation":"parks_and_rec", "Animal services (shelter, adoptions, animal control, etc.)":"animal_services","I feel safe in my neighborhood during the day":"safety_day","I feel safe in my neighborhood at night":"safety_night","I feel safe in city parks":"safety_parks","Number of City of Austin parks":"num_parks","Number of City of Austin walking/biking trails":"num_trails","Appearance of City of Austin park grounds located in Austin":"park_appearance","Which of the following best describes your AGE?":"age_range","Which of the following best describes your annual household income?":"income_range","Zip Code":"zip_code"})
# new_city_satisfaction_df.drop_duplicates("id", inplace=True)
new_city_satisfaction_df.set_index("id", inplace=True)
new_city_satisfaction_df.head()
# Out:
#       year quality_of_life parks_and_rec animal_services safety_day  \
# id
# 1873  2015         Neutral     Satisfied    Dissatisfied      Agree
# 1692  2015      Don't Know    Don't Know         Neutral    Neutral
# 1968  2015         Neutral       Neutral       Satisfied      Agree
# 1474  2015    Dissatisfied     Satisfied       Satisfied      Agree
# 1794  2015       Satisfied     Satisfied      Don't Know      Agree
#
#      safety_night safety_parks  num_parks num_trails park_appearance  \
# id
# 1873        Agree        Agree  Satisfied  Satisfied         Neutral
# 1692      Neutral     Disagree    Neutral    Neutral         Neutral
# 1968        Agree        Agree    Neutral    Neutral         Neutral
# 1474        Agree        Agree  Satisfied    Neutral         Neutral
# 1794        Agree        Agree  Satisfied  Satisfied       Satisfied
#
#          age_range    income_range  zip_code
# id
# 1873   18-34 years     $40K-59,999     78745
# 1692   35-44 years     $60K-79,999     78744
# 1968   18-34 years    $80K-149,999     78729
# 1474     65+ years  less than $20K     78741
# 1794     65+ years     $60K-79,999     78752

# %%
new_city_satisfaction_df.groupby(['year']).count()
# Out:
#       quality_of_life  parks_and_rec  animal_services  safety_day  \
# year
# 2015             2060           2060             2057        2060
# 2016             2099           2099             2099        2099
# 2017             2215           2215             2215        2215
#
#       safety_night  safety_parks  num_parks  num_trails  park_appearance  \
# year
# 2015          2060          2060       2060        2060             2059
# 2016          2099          2099       2099        2099             2099
# 2017          2215          2215       2215        2215             2215
#
#       age_range  income_range  zip_code
# year
# 2015       2060          2060      2060
# 2016       2099          2099      2099
# 2017       2215          2215      2215

# %% [markdown]
# ## Create Connection

# %%
# rds_connection_string = password
# engine = create_engine(f'mysql://root:{rds_connection_string}@localhost:3306/etlproject_db')

# %%
# # Confirm tables
# engine.table_names()

# %% [markdown]
# ## Load DataFrames into Database

# %%
new_aac_outcomes_df.to_sql('aac_outcomes', conn, if_exists='append', index=True)
# Out:
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# <ipython-input-22-1d1c8cd78b47> in <module>()
# ----> 1 new_aac_outcomes_df.to_sql('aac_outcomes', conn, if_exists='append', index=True)
#
# ~/anaconda3/envs/PythonData3/lib/python3.6/site-packages/pandas/core/generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype)
#    2128         sql.to_sql(self, name, con, schema=schema, if_exists=if_exists,
#    2129                    index=index, index_label=index_label, chunksize=chunksize,
# -> 2130                    dtype=dtype)
#    2131
#    2132     def to_pickle(self, path, compression='infer',
#
# ~/anaconda3/envs/PythonData3/lib/python3.6/site-packages/pandas/io/sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype)
#     448     pandas_sql.to_sql(frame, name, if_exists=if_exists, index=index,
#     449                       index_label=index_label, schema=schema,
# --> 450                       chunksize=chunksize, dtype=dtype)
#     451
#     452
#
# ~/anaconda3/envs/PythonData3/lib/python3.6/site-packages/pandas/io/sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype)
#    1479                             dtype=dtype)
#    1480         table.create()
# -> 1481         table.insert(chunksize)
#    1482
#    1483     def has_table(self, name, schema=None):
#
# ~/anaconda3/envs/PythonData3/lib/python3.6/site-packages/pandas/io/sql.py in insert(self, chunksize)
#     639
#     640                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 641                 self._execute_insert(conn, keys, chunk_iter)
#     642
#     643     def _query_iterator(self, result, chunksize, columns, coerce_float=True,
#
# ~/anaconda3/envs/PythonData3/lib/python3.6/site-packages/pandas/io/sql.py in _execute_insert(self, conn, keys, data_iter)
#    1268     def _execute_insert(self, conn, keys, data_iter):
#    1269         data_list = list(data_iter)
# -> 1270         conn.executemany(self.insert_statement(), data_list)
#    1271
#    1272     def _create_table_setup(self):
#
# IntegrityError: UNIQUE constraint failed: aac_outcomes.id

# %%
new_city_satisfaction_df.to_sql('city_satisfaction', conn, if_exists='append', index=True)
